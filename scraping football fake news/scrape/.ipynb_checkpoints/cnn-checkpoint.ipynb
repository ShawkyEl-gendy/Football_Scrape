# %%
import pandas as pd
import numpy as np
import requests 
from bs4 import BeautifulSoup

# %%
url=r"https://arabic.cnn.com/tag/alkrt-almsryt"

req=requests.get(url)
soup=BeautifulSoup(req.content,"html.parser")

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html data-reactroot="" dir="rtl" lang="ar">\n <head>\n  <meta charset="utf-8"/>\n  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>\n  <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>\n  <meta content="width=device-width,minimum-scale=1,initial-scale=1" name="viewport"/>\n  <meta content="origin-when-cross-origin" name="referrer"/>\n  <meta content="noarchive,noodp,noydir" name="robots"/>\n  <meta content="on" http-equiv="x-dns-prefetch-control"/>\n  <link href="/manifest-1.0.2.json" rel="manifest"/>\n  <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>\n  <link href="https://arabic.cnn.com" hreflang="x-default" rel="alternate"/>\n  <meta content="ar_AR" property="og:locale"/>\n  <meta content="CNN Arabic" property="og:site_name"/>\n  <meta content="102581028206" property="fb:pages"/>\n  <meta content="215296135184920" property="fb:app_id"/>\n  <meta content="@CNNARABIC" name="twitter:site"/>\n  <meta content="@CNNARABIC" name="twitter:creator"/>\n  <meta content="summary_large_image" name="twitter:card"/>\n  <meta content="arabic.cnn.com" name="twitter:domain"/>\n  <link href="https://cnn-arabic-images.cnn.io" rel="preconnect"/>\n  <link href="https://cnn-arabic-images.cnn.io" rel="dns-prefetch"/>\n  <link href="https://cdn.cnn.com" rel="preconnect"/>\n  <link href="https://cdn.cnn.com" rel="dns-prefetch"/>\n  <link href="https://lightning.cnn.com" rel="preconnect"/>\n  <link href="https://lightning.cnn.com" rel="dns-prefetch"/>\n  <link href="https://cdn.cookielaw.org" rel="preconnect"/>\n  <link href="https://cdn.cookielaw.org" rel="dns-prefetch"/>\n  <link href="https://smetrics.cnn.com" rel="dns-prefetch"/>\n  <link href="https://smetrics.cnn.com" rel="preconnect"/>\n  <link href="https://securepubads.g.doubleclick.net" rel="dns-prefetch"/>\n  <link href="https://securepubads.g.doubleclick.net" rel="preconnect"/>\n  <link href="//cdn.krxd.net" rel="dns-prefetch"/>\n  <link href="//mms.cnn.com" rel="dns-prefetch"/>\n  <link href="//js-sec.indexww.com" rel="dns-prefetch"/>\n  <link href="//www.googletagservices.com" rel="dns-prefetch"/>\n  <link href="//c.amazon-adsystem.com" rel="dns-prefetch"/>\n  <link href="//tpc.googlesyndication.com" rel="dns-prefetch"/>\n  <link href="//fastlane.rubiconproject.com" rel="dns-prefetch"/>\n  <link href="//optimized-by.rubiconproject.com" rel="dns-prefetch"/>\n  <link href="//gum.criteo.com" rel="dns-prefetch"/>\n  <link href="//bidder.criteo.com" rel="dns-prefetch"/>\n  <link href="//ib.adnxs.com" rel="dns-prefetch"/>\n  <link href="//prebid.adnxs.com" rel="dns-prefetch"/>\n  <link href="//acdn.adnxs.com" rel="dns-prefetch"/>\n  <link href="//static.adsafeprotected.com" rel="dns-prefetch"/>\n  <link href="//pixel.adsafeprotected.com" rel="dns-prefetch"/>\n  <link href="//secure.quantserve.com" rel="dns-prefetch"/>\n  <link href="//cdn.ml314.com" rel="dns-prefetch"/>\n  <link href="//segment-data-us-east.zqtk.net" rel="dns-prefetch"/>\n  <link href="//d2uap9jskdzp2.cloudfront.net" rel="dns-prefetch"/>\n  <link as="image" href="/images/icons/global/v001.svg" rel="preload" type="image/svg+xml"/>\n  <link as="font" crossorigin="anonymous" href="https://arabic.cnn.com/fonts/helvetica/1.0.0/a3bbc98e-e5f0-45ec-af25-e05e49dc2b5b.woff2" rel="preload" type="font/woff2"/>\n  <link as="font" crossorigin="anonymous" href="https://arabic.cnn.com/fonts/helvetica/1.0.0/33f381a3-597b-47c9-a038-ca7df1af0523.woff2" rel="preload" type="font/woff2"/>\n  <link as="script" href="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" rel="preload"/>\n  <link as="script" href="https://cdn.cnn.com/ads/adfuel/ais/2.1/cnna-ais.min.js" rel="preload"/>\n  <link as="script" href="https://cdn.cnn.com/ads/adfuel/adfuel-2.1.min.js" rel="preload"/>\n  <link data-chunk="index" href="https://arabic.cnn.com/build/1.06/client/index-b77691fb6b3dea6ef398.css" rel="stylesheet"/>\n  <link data-chunk="taxonomy" href="https://arabic.cnn.com/build/1.06/client/t ...

# %%
soup.find("p").text
# Out:
# 'يتطلع نادي الأهلي المصري للفوز على نظيره أوكلاند سيتي النيوزيلاندي، في مستهل مشواره في بطولة كأس العالم للأندية، المقرر إقامتها في المغرب بين 1 و11 فبراير/ شباط.'

# %%
news=[]
for x in np.arange(126,300):#all bages in site
    
    url=f"https://www.youm7.com/Section/%D8%A3%D8%AE%D8%A8%D8%A7%D8%B1-%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6%D8%A9/298/{x}"
    req=requests.get(url)
    soup=BeautifulSoup(req.content,"html.parser") 
    jn=soup.find_all("p") 
    for i in jn: 
        
        try:
            news.append(i.text) 
        except: 
            news.append(np.nan)

    news.pop()

# %%
news

# %%
len(news)

# %%
df=pd.DataFrame(data=news,columns=["tweet"])
df.to_csv("true2_test.csv",index=False)
