# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
from deep_translator import GoogleTranslator
import numpy as np

def transtale_ar_en(text):
    try:
        x = GoogleTranslator(source='ar',target='en').translate(text)
    except:
        x=np.nan
    return x

# %%
query='"😂" (الكورة OR الدوري OR الاهلي OR الزمالك OR الحارس OR اللاعب OR المدرب OR جون OR الحكم) lang:ar -filter:links -filter:replies'
limit=5000
tweets=[]

for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    #print(vars(tweet))
    #break
    if len(tweets)==limit:
        break
    else:
        tweets.append([tweet.content])
    
df_EgyptionLeague=pd.DataFrame(tweets,columns=['tweet'])
df_EgyptionLeague
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_1740/174029641.py:11: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweets.append([tweet.content])
#                                                   tweet
# 0     كويتي سكران بالمقرب طاح من الدرج غاله الحارس ب...
# 1     شكل الاهلي بينزل درجه ثانيه \nالشغله فيها خصم ...
# 2     يعنى فترة توقف منافسات الكوره الواحد يروق شوي ...
# 3     الهلال ادي الامل للأهلي في افريقيا ،وخلاهم ميش...
# 4     دعوة لكل كتكوت بيشجع عشة الفراخ ولكل فرخة وديك...
# ...                                                 ...
# 4995  الاهلي  بقي اول فريق يتعشر في افريقيا 😂😂😂😂😂\n#...
# 4996  ياريت لعيبة الدوري تكون فهمت وعرفت إن الشخناوي...
# 4997  ما يفسده الاهلي تفسده برشلونه وتكمل علينا..طب ...
# 4998  كفارا نابولي جابه ببلاش وحرفيا بيعمل كل حاجه ف...
# 4999  الزمالك بعد ما اتفتحت كل شوارعها حاسس اني رجعت...
#
# [5000 rows x 1 columns]

# %%
query='"😉" (الكورة OR الدوري OR الاهلي OR الزمالك OR الحارس OR اللاعب OR المدرب OR جون OR الحكم) lang:ar -filter:links -filter:replies'
limit=5000
tweets=[]

for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    #print(vars(tweet))
    #break
    if len(tweets)==limit:
        break
    else:
        tweets.append([tweet.content])
    
df_EgyptionLeague_fake2=pd.DataFrame(tweets,columns=['tweet'])
df_EgyptionLeague_fake2
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_1740/1517505185.py:11: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweets.append([tweet.content])
# Tweet 1627684507276165121 contains an app icon medium key '4_1637565530335858691' on app 'android_app'/'com.bluapp.customer', but the corresponding medium is missing; dropping
# Tweet 1623705783333539841 contains an app icon medium key '4_1637511406852472834' on app 'iphone_app'/'1271754138', but the corresponding medium is missing; dropping
# Tweet 1623705783333539841 contains an app icon medium key '4_1637511406852472834' on app 'ipad_app'/'1271754138', but the corresponding medium is missing; dropping
#                                                   tweet
# 0     "المضحك": \nإستبعدوا من المنتخب أكثر لعيبه نشا...
# 1                       جون لاتنزل شييي لين أصحى اوكي؟😉
# 2     راح يوقفون الدوري اسبوعين عشان منتخب الهلال......
# 3     مبدئيآ الدوري شبه اتحسم و الكاس موجودين فيه + ...
# ...

# %%
fake_df=pd.concat([df_EgyptionLeague,df_EgyptionLeague_fake2],ignore_index=True)

# %%
fake_df=fake_df.sample(frac=1).reset_index(drop=True)
fake_df.head()
# Out:
#                                                tweet
# 0                      مبسوط ان الحكم ماحسب بلنتي 😭😂
# 1  عندما تصادف اي كلام او غيره عن الاهلي … تذكر ا...
# 2                     بوبو فى النادى الاهلى ..... 😉😉
# 3  هما محروقين كده ليه اوي علي كلاتينبرج و سمعة م...
# 4  والله مهزله على تأجيل الدوري 😂😂\n\nكل هذا عشان...

# %%
fake_df.to_csv("twitter_fake.csv",index=True)

# %%
query='"هههه" (الكورة OR الدوري OR الاهلي OR الزمالك OR الحارس OR اللاعب OR المدرب OR جون OR الحكم OR جون OR هدف OR تسلل OR دفاع OR هجوم OR مهاجم) lang:ar -filter:links -filter:replies'
limit=10000
tweets=[]

for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    #print(vars(tweet))
    #break
    if len(tweets)==limit:
        break
    else:
        tweets.append([tweet.content])
    


df_EgyptionLeague_fake2=pd.DataFrame(tweets,columns=['tweet'])
df_EgyptionLeague_fake2
# Out:
#                                                   tweet
# 0     مباراة الهلال وصن فكرتني بأغنية الفول صديقي وا...
# 1                             صباااااح غريب بس حلو هههه
# 2     والله ماعندي مشكله برشلونه يحقق الدوري لو بفار...
# 3                يحيا العدل يحيا العدل \nتسلل واضح هههه
# 4     صاروخ كريستيانو عبد الفتاح ادم النصراوي يضيع ا...
# ...                                                 ...
# 9995  يقولك في خبر المدرب طلب هذا اللاعب بس جابوله ل...
# 9996  الهلال راح يدعس على هيئة الرياضة بكاملها لان ا...
# 9997  عن البنت إلى بتصلى ❤\nوبتشجع الأهلى 😍\nوبتلبس ...
# 9998  المختلط بعد هزيمه الأهلي بيلعب الآن مع الإنتاج...
# 9999  أسمه رب ربرالي هههه #مانشستر_سيتي #غرد_للسيتي\...
#
# [10000 rows x 1 columns]

# %%
len(tweets)
# Out:
# 10000

# %%
df_EgyptionLeague_fake2.to_csv("twitter_fake2.csv",index=True)

# %% [markdown]
# # Treu Data

# %%
query='(from:EFA) lang:ar -filter:links -filter:replies'
limit=5000
tweets=[]

for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    #print(vars(tweet))
    #break
    if len(tweets)==limit:
        break
    else:
        tweets.append([tweet.content])
    
df_EgyptionLeague_true1=pd.DataFrame(tweets,columns=['tweet'])
df_EgyptionLeague_true1
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_1740/3116901453.py:11: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweets.append([tweet.content])
#                                                  tweet
# 0    🔴 أسعار تذاكر أمم افريقيا للشباب 🇪🇬🏆 \nحدد الا...
# 1    🔴  |  نفاد تذاكر ودية منتخب مصر وكوريا الجنوبي...
# 2    🔴  |  جمال علام و أبو الوفا  يدعمان منتخب الشا...
# 3    بسبب أحداث السنغال ..مصر تستضيف مؤتمرا  عالميا...
# 4    🔴 📸  |  اتحاد الكرة يقيم حفل الإفطار السنوي …....
# ..                                                 ...
# 760  ادت بعثة المنتخب الوطني في بورت جنتي ظهر اليوم...
# 761  انتهاء الشوط الاول بالتعادل السلبى بين منتخب ا...
# 762  انذار للاعب على معلول لتحركة اثناء تنفيذ ضربة ...
# 763  الآن .. بعد انتهاء محاضرة الفيديو واستعداد الل...
# 764  اجواء معسكر المنتخب الوطني في بورت جنتيل صباح ...
#
# [765 rows x 1 columns]

# %%
query='(#أخبار_ONTime) (from:ONTimeSports)'
limit=10000
tweets=[]

for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    #print(vars(tweet))
    #break
    if len(tweets)==limit:
        break
    else:
        tweets.append([tweet.content])
    
df_EgyptionLeague_true0=pd.DataFrame(tweets,columns=['tweet'])
df_EgyptionLeague_true0
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_1740/2309968144.py:11: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweets.append([tweet.content])
#                                                   tweet
# 0     باتشيكو: بيراميدز خسر من الجيش الملكي بخطأ ساذ...
# 1     "سامي قمصان يقود تدريبات الأهلي لحين عودة كولر...
# 2     "الزمالك يتواصل مع الإفريقي التونسي لإنهاء أزم...
# 3     مباريات اليوم في بطولة كأس الرابطة🏆\n#أخبار_ON...
# 4     ميكالي يسمح لوسائل الإعلام📺📺 بحضور تدريب المنت...
# ...                                                 ...
# 3179  شيما صابر تكشف عن رسالة شديدة اللهجة من المسؤو...
# 3180  حصرياااا.. شيما صابر تكشف كواليس جلسة موسيماني...
# 3181  تعديلات في خطة الأهلي وتشكيله في لقاء الغد أما...
# 3182  تعرف على مواعيد مباريات الجولة الثانية من مباي...
# 3183  مقدمة شيما في أول حلقات برنامجج #أخبار_ONTime ...
#
# [3184 rows x 1 columns]

# %%
#df_EgyptionLeague_true2.to_csv("twitter_true2.csv",index=True)

# %%
df_EgyptionLeague_true0
# Out:
#                                                   tweet
# 0     باتشيكو: بيراميدز خسر من الجيش الملكي بخطأ ساذ...
# 1     "سامي قمصان يقود تدريبات الأهلي لحين عودة كولر...
# 2     "الزمالك يتواصل مع الإفريقي التونسي لإنهاء أزم...
# 3     مباريات اليوم في بطولة كأس الرابطة🏆\n#أخبار_ON...
# 4     ميكالي يسمح لوسائل الإعلام📺📺 بحضور تدريب المنت...
# ...                                                 ...
# 3179  شيما صابر تكشف عن رسالة شديدة اللهجة من المسؤو...
# 3180  حصرياااا.. شيما صابر تكشف كواليس جلسة موسيماني...
# 3181  تعديلات في خطة الأهلي وتشكيله في لقاء الغد أما...
# 3182  تعرف على مواعيد مباريات الجولة الثانية من مباي...
# 3183  مقدمة شيما في أول حلقات برنامجج #أخبار_ONTime ...
#
# [3184 rows x 1 columns]

# %%
query='(from:ShobierOfficial) -filter:links -filter:replies'
limit=2000
tweets=[]

for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    #print(vars(tweet))
    #break
    if len(tweets)==limit:
        break
    else:
        tweets.append([tweet.content])
    
df_EgyptionLeague_true2=pd.DataFrame(tweets,columns=['tweet'])
df_EgyptionLeague_true2
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_1740/2961259325.py:11: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweets.append([tweet.content])
#                                                   tweet
# 0     الف حمد الله علي سلامة الكابتن محمد عامر خرج م...
# 1     مره تانيه وتالته كوللر رافض اصلا المشاركه في ك...
# 2                                  انما الأعمال بالنيات
# 3     كهربا يستاهل .. مروان يستحق.. كوللر رافض المشا...
# 4                    الف مبروك لكهربا العوده لمنتخب مصر
# ...                                                 ...
# 1995  اول صفقات الشتاء في الاهلي لاعب صاعد الي الجون...
# 1996  ياللا بينا توقعاتكم لنتيجة مباراة الاهلي ووادي...
# 1997  كل سنه وانتم طيبين والسنه الجايه احلي واجمل عل...
# 1998  كورونا يضرب الاهلي من جديد محمد هاني ..اكرم تو...
# 1999  ان شاء الله كل الفائزين  في مسابقة التوقعات هي...
#
# [2000 rows x 1 columns]

# %%
query='(from:seifzahersocial) -filter:links -filter:replies'
limit=2000
tweets=[]

for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    #print(vars(tweet))
    #break
    if len(tweets)==limit:
        break
    else:
        tweets.append([tweet.content])
    
df_EgyptionLeague_true3=pd.DataFrame(tweets,columns=['tweet'])
df_EgyptionLeague_true3
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_1740/3528185942.py:11: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweets.append([tweet.content])
#                                                   tweet
# 0      فتحي سند : سباق الدوري سيحسم مبكرًا لصالح الأهلي
# 1     وكيل أحمد بلحاج: فوجئت بانتشار خطابي لاتحاد ال...
# 2     أحمد دياب: السوشيال ميديا أثرت على قرارات التحكيم
# 3     أحمد دياب: التحكيم لم يكن الأفضل في عهد كلاتنب...
# 4     أحمد دياب: شكاوى الأنديه سبب اجتماعنا مع لجنة ...
# ...                                                 ...
# 1995  كريم فؤاد لاعب إنبي ومنتخب مصر الأولمبي في مدا...
# 1996  اكتمل عقد دور الثمانية لدوري أبطال أوروبا .. \...
# 1997  بطل القارة يصول و يجول فى الأدغال، قدم مباراة ...
# 1998  عمرو الدردير: كارتيرون مدرب اسطوري في المباريا...
# 1999  علاء عزت : موسيماني قد يستمر مع الأهلي لنهاية ...
#
# [2000 rows x 1 columns]

# %%
query='(from:MedhatShalaby9) -filter:links -filter:replies'
limit=2000
tweets=[]

for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    #print(vars(tweet))
    #break
    if len(tweets)==limit:
        break
    else:
        tweets.append([tweet.content])
    
df_EgyptionLeague_true4=pd.DataFrame(tweets,columns=['tweet'])
df_EgyptionLeague_true4
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_1740/1318130473.py:11: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweets.append([tweet.content])
#                                                   tweet
# 0     سؤال الحلقة .. رتب الفرق الثلاثه الأولى في نها...
# 1     سؤال الحلقة .. أختار الهدف الافضل من أهداف الا...
# 2     سؤال الحلقة .. من وجهة نظرك  هل سيحسم لقب الدو...
# 3     سؤال الحلقة .. أختار الافضل من الاهداف \nأحمد ...
# 4     تشكيلة الاهلى\nالشناوى \nفتحى \nايمن \nياسر\nم...
# ...                                                 ...
# 1995  مجلس الاتحاد يصرف4000 جنيه مكافأة الفوز على ال...
# 1996  الأهلي يؤكد غياب صالح جمعة عن لقاء ريكرياتيفو ...
# 1997  الزمالك: لا صحة لرفض حمودي تخفيض قيمة عقده للا...
# 1998  الأهلي يؤكد موافقة الأمن على حضور200من أعضاء ا...
# 1999  ليفربول  يتعادل مع مانشستر يونايتد 1-1ويتأهل ل...
#
# [2000 rows x 1 columns]

# %%
true_df=pd.concat([df_EgyptionLeague_true0,df_EgyptionLeague_true1,df_EgyptionLeague_true2,df_EgyptionLeague_true3,df_EgyptionLeague_true4],ignore_index=True)

# %%
true_df=true_df.sample(frac=1).reset_index(drop=True)

# %%
true_df.shape
# Out:
# (9949, 1)

# %%
true_df.to_csv("twitter_true.csv",index=True)
